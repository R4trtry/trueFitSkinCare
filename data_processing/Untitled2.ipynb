# %%
import re
import MySQLdb
import pandas as pd
# import 
import numpy as np
import math
from scipy.sparse import csr_matrix
from scipy.sparse import isspmatrix_csc
from sklearn.metrics.pairwise import cosine_similarity
from collections import Counter
from collections import OrderedDict


def sql2df(sql):
    con = MySQLdb.connect('localhost', 'root', '', 'insight')
    with con:
        cur = con.cursor(MySQLdb.cursors.DictCursor)
        df = pd.read_sql_query(sql,con)
    return df

# filter the recommendations with category 
# return a list sorted by recommendation score
def cate_filter(score, category, product_list):
    score[np.array(product_list['category']!=category)]=float('nan')
    score = [sqrt(s) for s in score]
    product_list['score']=score
    return product_list.sort('score',ascending=False)

# recommend list of product in [category] by comparing [usrProfile]
# with [simMatrix]
def recommender(simMatrix, usrProfile, category, product_list):
    
    print "Making recommendations score..."
    # score = simMatrix[usrProfile].sum(0)
    score = simMatrix[usrProfile[0]]
    score[score==0]=float('nan')
    score=np.nanmean(score,0)
#     score=np.array(usrProfile[1])*np.array(score).transpose()
#     score = np.nanmean(score,1)
    product_c = cate_filter(score,category,product_list)
    
    # normalizing the score such that it's 1-5
    product_c['score']=product_c['score']/product_c['score'].max()*4+1
    return product_c

def prepare_itemcentric():
    product_list = sql2df('select distinct product_id, category from Product order by category, brand;')
    product_id = product_list['product_id'].tolist()
    reviewer_list = sql2df("""select reviewer_id from 
        (select reviewer_id, reviewer_name, count(Review.review_id) as c 
        from Reviewer join Review
        where Review.review_id = Reviewer.review_id 
        group by reviewer_id 
        order by reviewer_id) 
        as review_counts 
        where review_counts.c > 4;""")
    reviewer_id = reviewer_list['reviewer_id'].tolist()
    ratings = sql2df("""select reviewer_id, product_id, rating
            from Reviewer join Review
            where Review.review_id = Reviewer.review_id """)
    category_list = product_list['category']

    product_reviewer = []
    # Construct a matrix where one dimension is product, the other is reviewer, the value is rating
    # so for each product in the list
    counter = 0
    for product in product_id:
        counter += 1
        if counter %10 ==0:
            print "Product scanned: " + str(counter) + "/1177 ..."
        # grab all the ratings for that product
        product_rating = ratings[ratings['product_id']==product].drop('product_id',1).set_index('reviewer_id').to_dict()['rating']

        score = dict.fromkeys(reviewer_id,0)
        for key in product_rating.keys():
            if key not in reviewer_id:
                continue
            score[key] = product_rating[key]
        product_reviewer.append(score.values())

    print "Calculating similarity score..."
    sim = cosine_similarity(product_reviewer,product_reviewer)
    # sim[sim>.99] = 0

    print "Saving similarity matrix to csv..."
    np.savetxt("sim_product.csv", sim, delimiter=",")
    np.savetxt("sim_product2.csv", sim, delimiter=",", fmt='%.2f')
    return sim

# %%
# category='face-wash-facial-cleanser'
# category = 'face-serum'
category = 'moisturizer-skincare'
# sim = prepare_itemcentric()
sim = np.loadtxt("sim_product.csv",delimiter=',')
product_list = sql2df('select distinct product_id, category from Product order by category, brand;')
product_c = recommender(sim, [[926, 1166, 559, 1099, 246, 688, 690],[5,4,5,5,5,4,5]], category, product_list)
# Out:
# Making recommendations score...

# %%
product_c[:int(round(len(product_c[product_c['score']>1])/5))]
# Out:
#      product_id              category     score
# 1099    P214002  moisturizer-skincare  5.000000
# 926     P377268  moisturizer-skincare  4.824048
# 1147    P385511  moisturizer-skincare  4.687810
# 1102    P384805  moisturizer-skincare  4.401364
# 921     P381434  moisturizer-skincare  4.156027
# 832     P387076  moisturizer-skincare  4.072639
# 948     P375954  moisturizer-skincare  3.778716
# 1075    P377562  moisturizer-skincare  3.762595
# 1096    P174631  moisturizer-skincare  3.734252
# 1000    P158703  moisturizer-skincare  3.685913
# 945     P213204  moisturizer-skincare  3.683142
# 1062    P388121  moisturizer-skincare  3.607675
# 823     P378500  moisturizer-skincare  3.607675
# 900     P378607  moisturizer-skincare  3.597587
# 969     P232918  moisturizer-skincare  3.523632
# 934     P378335  moisturizer-skincare  3.460727
# 1066    P294205  moisturizer-skincare  3.428908
# 1101    P380810  moisturizer-skincare  3.421728
# 834     P189300  moisturizer-skincare  3.397741
# 953     P234456  moisturizer-skincare  3.365844
# 856     P309205  moisturizer-skincare  3.356765
# 1054    P376634  moisturizer-skincare  3.346141
# 847     P201429  moisturizer-skincare  3.343266
# 1108    P312915  moisturizer-skincare  3.301531
# 988     P387652  moisturizer-skincare  3.245831
# 924     P263006  moisturizer-skincare  3.235764
# 1058    P379851  moisturizer-skincare  3.203888
# 935     P385043  moisturizer-skincare  3.197089
# 1013    P281201  moisturizer-skincare  3.192785
# 850     P242916  moisturizer-skincare  3.132038
# 1137    P375844  moisturizer-skincare  3.121037
# 803     P281828  moisturizer-skincare  3.119378
# 922     P248407  moisturizer-skincare  3.114107
# 1097    P214000  moisturizer-skincare  3.112339
# 990      P96603  moisturizer-skincare  3.108568
# 1065    P211331  moisturizer-skincare  3.104954
# 892     P302938  moisturizer-skincare  3.072508
# 896     P122308  moisturizer-skincare  3.062065
# 976     P386715  moisturizer-skincare  3.061045
# 1069    P196004  moisturizer-skincare  3.045657
# 925     P375534  moisturizer-skincare  3.040106
# 818     P270595  moisturizer-skincare  3.038699
# 868     P247716  moisturizer-skincare  3.021372
# 1070    P297703  moisturizer-skincare  3.019897
# 1026      P4040  moisturizer-skincare  3.007852
# 1107    P297131  moisturizer-skincare  2.998843
# 991      P96804  moisturizer-skincare  2.982703

# %%
# Out:
# 235.0
